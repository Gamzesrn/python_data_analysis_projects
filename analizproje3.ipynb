# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df=pd.read_excel("merc.xlsx")

# %%
df
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 0      2005   5200    Automatic    63000  325  32.1         1.8
# 1      2017  34948    Automatic    27000   20  61.4         2.1
# 2      2016  49948    Automatic     6200  555  28.0         5.5
# 3      2016  61948    Automatic    16000  325  30.4         4.0
# 4      2016  73948    Automatic     4000  325  30.1         4.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 13114  2020  35999    Automatic      500  145  55.4         2.0
# 13115  2020  24699    Automatic     2500  145  55.4         2.0
# 13116  2019  30999    Automatic    11612  145  41.5         2.1
# 13117  2019  37990    Automatic     2426  145  45.6         2.0
# 13118  2019  54999    Automatic     2075  145  52.3         2.9
#
# [13119 rows x 7 columns]

# %%
df.shape
# Out:
# (13119, 7)

# %%
df.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
df.tail()
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 13114  2020  35999    Automatic      500  145  55.4         2.0
# 13115  2020  24699    Automatic     2500  145  55.4         2.0
# 13116  2019  30999    Automatic    11612  145  41.5         2.1
# 13117  2019  37990    Automatic     2426  145  45.6         2.0
# 13118  2019  54999    Automatic     2075  145  52.3         2.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          13119 non-null  int64
#  1   price         13119 non-null  int64
#  2   transmission  13119 non-null  object
#  3   mileage       13119 non-null  int64
#  4   tax           13119 non-null  int64
#  5   mpg           13119 non-null  float64
#  6   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 717.6+ KB

# %%
df.dtypes
# Out:
# year              int64
# price             int64
# transmission     object
# mileage           int64
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df.isnull().any()
# Out:
# year            False
# price           False
# transmission    False
# mileage         False
# tax             False
# mpg             False
# engineSize      False
# dtype: bool

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df.describe().T
# Out:
#               count          mean           std     min      25%      50%  \
# year        13119.0   2017.296288      2.224709  1970.0   2016.0   2018.0
# price       13119.0  24698.596920  11842.675542   650.0  17450.0  22480.0
# mileage     13119.0  21949.559037  21176.512267     1.0   6097.5  15189.0
# tax         13119.0    129.972178     65.260286     0.0    125.0    145.0
# mpg         13119.0     55.155843     15.220082     1.1     45.6     56.5
# engineSize  13119.0      2.071530      0.572426     0.0      1.8      2.0
#
#                 75%       max
# year         2019.0    2020.0
# price       28980.0  159999.0
# mileage     31779.5  259000.0
# tax           145.0     580.0
# mpg            64.2     217.3
# engineSize      2.1       6.2

# %%
df.describe(include="all")
# Out:
#                 year          price transmission        mileage           tax  \
# count   13119.000000   13119.000000        13119   13119.000000  13119.000000
# unique           NaN            NaN            4            NaN           NaN
# top              NaN            NaN    Semi-Auto            NaN           NaN
# freq             NaN            NaN         6848            NaN           NaN
# mean     2017.296288   24698.596920          NaN   21949.559037    129.972178
# std         2.224709   11842.675542          NaN   21176.512267     65.260286
# min      1970.000000     650.000000          NaN       1.000000      0.000000
# 25%      2016.000000   17450.000000          NaN    6097.500000    125.000000
# 50%      2018.000000   22480.000000          NaN   15189.000000    145.000000
# 75%      2019.000000   28980.000000          NaN   31779.500000    145.000000
# max      2020.000000  159999.000000          NaN  259000.000000    580.000000
#
# ...

# %%
df.describe(include="all").T
# Out:
#                 count unique        top  freq          mean           std  \
# year          13119.0    NaN        NaN   NaN   2017.296288      2.224709
# price         13119.0    NaN        NaN   NaN   24698.59692  11842.675542
# transmission    13119      4  Semi-Auto  6848           NaN           NaN
# mileage       13119.0    NaN        NaN   NaN  21949.559037  21176.512267
# tax           13119.0    NaN        NaN   NaN    129.972178     65.260286
# mpg           13119.0    NaN        NaN   NaN     55.155843     15.220082
# engineSize    13119.0    NaN        NaN   NaN       2.07153      0.572426
#
#                  min      25%      50%      75%       max
# year          1970.0   2016.0   2018.0   2019.0    2020.0
# price          650.0  17450.0  22480.0  28980.0  159999.0
# transmission     NaN      NaN      NaN      NaN       NaN
# mileage          1.0   6097.5  15189.0  31779.5  259000.0
# tax              0.0    125.0    145.0    145.0     580.0
# ...

# %%
df.columns
# Out:
# Index(['year', 'price', 'transmission', 'mileage', 'tax', 'mpg', 'engineSize'], dtype='object')

# %%
df.nunique()
# Out:
# year              25
# price           4424
# transmission       4
# mileage         9716
# tax               40
# mpg              120
# engineSize        26
# dtype: int64

# %%
df["transmission"].unique()
# Out:
# array(['Automatic', 'Manual', 'Semi-Auto', 'Other'], dtype=object)

# %%
df["year"].value_counts()
# Out:
# 2019    4553
# 2017    2381
# 2016    1971
# 2018    1467
# 2015     991
# 2020     719
# 2014     491
# 2013     292
# 2012      57
# 2011      38
# 2010      38
# 2007      22
# 2009      17
# 2008      16
# 2004      13
# 2001      10
# 2002       9
# 2005       9
# 2006       8
# 2003       7
# 1998       4
# 2000       3
# 1997       1
# 1999       1
# 1970       1
# Name: year, dtype: int64

# %%
df["price"].value_counts()
# Out:
# 24999    48
# 19999    46
# 17999    44
# 14999    42
# 19000    40
#          ..
# 34795     1
# 57400     1
# 22678     1
# 42480     1
# 19344     1
# Name: price, Length: 4424, dtype: int64

# %%
df["mileage"].value_counts()
# Out:
# 1000     324
# 16        62
# 3999      61
# 2000      59
# 9         45
#         ...
# 13250      1
# 31870      1
# 21055      1
# 10537      1
# 2426       1
# Name: mileage, Length: 9716, dtype: int64

# %%
df["tax"].value_counts()
# Out:
# 145    7645
# 20     1251
# 125    1013
# 30      989
# 150     855
# 200     276
# 160     188
# 0       172
# 260     123
# 300      99
# 165      65
# 325      64
# 205      63
# 235      52
# 135      48
# 305      38
# 265      36
# 555      28
# 570      25
# 330      18
# 240      15
# 140      14
# 565       8
# 580       4
# 540       3
# 115       3
# 270       3
# 190       3
# 315       2
# 10        2
# 230       2
# 290       2
# 250       2
# 255       2
# 220       1
# 280       1
# 195       1
# 520       1
# 185       1
# 210       1
# Name: tax, dtype: int64

# %%
df["mpg"].value_counts()
# Out:
# 56.5     1028
# 64.2      877
# 65.7      692
# 67.3      622
# 68.9      611
#          ...
# 28.3        1
# 122.9       1
# 21.7        1
# 42.4        1
# 19.5        1
# Name: mpg, Length: 120, dtype: int64

# %%
df["engineSize"].value_counts()
# Out:
# 2.1    4018
# 2.0    3739
# 1.5    1675
# 3.0    1355
# 1.6     843
# 1.3     716
# 4.0     197
# 2.2     124
# 2.9     120
# 1.8     113
# 2.3      73
# 5.5      44
# 4.7      24
# 3.5      19
# 6.2      13
# 3.2      13
# 0.0      12
# 5.0       6
# 2.7       5
# 6.0       2
# 3.7       2
# 1.7       2
# 2.5       1
# 5.4       1
# 4.3       1
# 1.4       1
# Name: engineSize, dtype: int64

# %%
df["engineSize"].mean()
# Out:
# 2.071529842213366

# %%
df["mpg"].mean()
# Out:
# 55.155842670936934

# %%
df["tax"].count()
# Out:
# 13119

# %%
categorical_columns = df.select_dtypes("object")
numerical_columns = df.select_dtypes("int64")

# %%
categorical_columns
# Out:
#       transmission
# 0        Automatic
# 1        Automatic
# 2        Automatic
# 3        Automatic
# 4        Automatic
# ...            ...
# 13114    Automatic
# 13115    Automatic
# 13116    Automatic
# 13117    Automatic
# 13118    Automatic
#
# [13119 rows x 1 columns]

# %%
px.histogram(categorical_columns,x ='transmission')

# %%
numerical_columns
# Out:
#        year  price  mileage  tax
# 0      2005   5200    63000  325
# 1      2017  34948    27000   20
# 2      2016  49948     6200  555
# 3      2016  61948    16000  325
# 4      2016  73948     4000  325
# ...     ...    ...      ...  ...
# 13114  2020  35999      500  145
# 13115  2020  24699     2500  145
# 13116  2019  30999    11612  145
# 13117  2019  37990     2426  145
# 13118  2019  54999     2075  145
#
# [13119 rows x 4 columns]

# %%
df1=df.groupby("year")[["mileage"]].mean().reset_index()
df1
# Out:
#     year       mileage
# 0   1970  14000.000000
# 1   1997  76000.000000
# 2   1998  76347.750000
# 3   1999  34000.000000
# 4   2000  89648.666667
# 5   2001  72955.100000
# 6   2002  57391.111111
# 7   2003  88777.714286
# 8   2004  94363.461538
# 9   2005  80651.333333
# 10  2006  94347.375000
# 11  2007  80309.000000
# 12  2008  81442.437500
# 13  2009  92207.941176
# 14  2010  83562.894737
# 15  2011  69977.868421
# 16  2012  64673.175439
# 17  2013  55377.958904
# 18  2014  48007.572301
# 19  2015  43099.799193
# 20  2016  34236.487570
# 21  2017  26448.897522
# 22  2018  15242.110429
# 23  2019   6988.832199
# 24  2020   1996.468707

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=df1,x ='year',y="mileage",palette="pastel")
# Out:
# <AxesSubplot:xlabel='year', ylabel='mileage'>

# %%
px.bar(df1,x ='year',y="mileage")

# %%
px.histogram(df,x ='mileage')

# %%
px.histogram(df1,x ='mileage')

# %%
df2=df.groupby("transmission")[["price"]].mean().reset_index()
df2
# Out:
#   transmission         price
# 0    Automatic  24406.959585
# 1       Manual  15442.434903
# 2        Other  15847.500000
# 3    Semi-Auto  26858.461157

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=df2,x ='transmission',y="price",palette="pastel")
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='price'>

# %%
px.bar(df2,x ='transmission',y="price")

# %%
df3=df.groupby("year")[["tax","price"]].mean().reset_index()
df3
# Out:
#     year         tax         price
# 0   1970  305.000000  24999.000000
# 1   1997  255.000000   9995.000000
# 2   1998  262.500000   8605.000000
# 3   1999  145.000000   5995.000000
# 4   2000  268.333333   5743.333333
# 5   2001  347.500000   4957.900000
# 6   2002  350.555556   5820.444444
# 7   2003  300.000000   4878.000000
# 8   2004  312.307692   4727.615385
# 9   2005  303.333333   4426.111111
# 10  2006  412.500000   4036.875000
# 11  2007  351.136364   5136.045455
# 12  2008  342.812500   6967.437500
# 13  2009  295.000000   6166.764706
# 14  2010  317.763158   8308.473684
# 15  2011  246.315789  12624.894737
# 16  2012  175.087719  10845.140351
# 17  2013  132.688356  11939.842466
# 18  2014   99.511202  14042.936864
# 19  2015   96.493441  16731.780020
# 20  2016   88.959919  19307.892948
# 21  2017  120.842083  21514.307854
# 22  2018  147.256305  25720.162918
# 23  2019  146.504503  31290.020865
# 24  2020  145.660640  35433.282337

# %%
px.bar(df3, x="year", y="price",color="tax")

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=df3,x ='year',y="price",palette="pastel")
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=df3,x ='year',y="tax",palette="pastel")
# Out:
# <AxesSubplot:xlabel='year', ylabel='tax'>

# %%
px.line(df3, x = "year", y = "price")

# %%
px.line(df3, x = "year", y = "tax")

# %%
data=df[df['transmission']=="Automatic"]
data
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 0      2005   5200    Automatic    63000  325  32.1         1.8
# 1      2017  34948    Automatic    27000   20  61.4         2.1
# 2      2016  49948    Automatic     6200  555  28.0         5.5
# 3      2016  61948    Automatic    16000  325  30.4         4.0
# 4      2016  73948    Automatic     4000  325  30.1         4.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 13114  2020  35999    Automatic      500  145  55.4         2.0
# 13115  2020  24699    Automatic     2500  145  55.4         2.0
# 13116  2019  30999    Automatic    11612  145  41.5         2.1
# 13117  2019  37990    Automatic     2426  145  45.6         2.0
# 13118  2019  54999    Automatic     2075  145  52.3         2.9
#
# [4825 rows x 7 columns]

# %%
sns.pairplot(df)

# %%
gender_counts = df["transmission"].value_counts(normalize=True)

counts = {}
for col in df.columns:
    counts[col] = df[col].value_counts(normalize=True)

# %%
plt.figure(figsize=(5,5))
plt.pie(counts["transmission"], labels=counts["transmission"].index)
plt.title("transmission Distribution")
# Out:
# Text(0.5, 1.0, 'transmission Distribution')

# %%
sns.barplot(x="transmission",y="tax",data=df,palette="pastel");

# %%
sns.barplot(x="transmission",y="price",data=df);

# %%
sns.boxplot(x="transmission",y="mpg",data=df);
