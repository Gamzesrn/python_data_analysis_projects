# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %%
# %matplotlib inline

# %%
df =pd.read_csv("gender.csv")
df
# Out:
#       Gender   Age   Height (cm)   Weight (kg)             Occupation  \
# 0       male    32           175            70      Software Engineer
# 1       male    25           182            85   Sales Representative
# 2     female    41           160            62                 Doctor
# 3       male    38           178            79                 Lawyer
# 4     female    29           165            58       Graphic Designer
# ..       ...   ...           ...           ...                    ...
# 126   female    32           170            64                  Nurse
# 127     male    38           176            79        Project Manager
# 128   female    27           162            55       Graphic Designer
# 129     male    33           175            77   Sales Representative
# 130   female    29           164            57     Software Developer
#
#          Education Level  Marital Status   Income (USD)  Favorite Color  \
# ...

# %%
df.head()
# Out:
#     Gender   Age   Height (cm)   Weight (kg)             Occupation  \
# 0     male    32           175            70      Software Engineer
# 1     male    25           182            85   Sales Representative
# 2   female    41           160            62                 Doctor
# 3     male    38           178            79                 Lawyer
# 4   female    29           165            58       Graphic Designer
#
#        Education Level  Marital Status   Income (USD)  Favorite Color  \
# 0      Master's Degree         Married          75000            Blue
# 1    Bachelor's Degree          Single          45000           Green
# 2     Doctorate Degree         Married         120000          Purple
# 3    Bachelor's Degree          Single          90000             Red
# 4   Associate's Degree          Single          35000          Yellow
#
#    Unnamed: 9
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.tail()
# Out:
#      Gender   Age   Height (cm)   Weight (kg)            Occupation  \
# 126  female    32           170            64                 Nurse
# 127    male    38           176            79       Project Manager
# 128  female    27           162            55      Graphic Designer
# 129    male    33           175            77  Sales Representative
# 130  female    29           164            57    Software Developer
#
#         Education Level  Marital Status   Income (USD)  Favorite Color  \
# 126  Associate's Degree          Single          60000          Orange
# 127   Bachelor's Degree         Married          90000           Black
# 128  Associate's Degree          Single          55000           Green
# 129   Bachelor's Degree         Married          80000          Yellow
# 130   Bachelor's Degree          Single          65000            Blue
#
#      Unnamed: 9
# 126         NaN
# 127         NaN
# 128         NaN
# 129         NaN
# 130         NaN

# %%
df.shape
# Out:
# (131, 10)

# %%
df.dtypes
# Out:
#  Gender              object
#  Age                  int64
#  Height (cm)          int64
#  Weight (kg)          int64
#  Occupation          object
#  Education Level     object
#  Marital Status      object
#  Income (USD)         int64
#  Favorite Color      object
# Unnamed: 9          float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0    Gender           131 non-null    object
#  1    Age              131 non-null    int64
#  2    Height (cm)      131 non-null    int64
#  3    Weight (kg)      131 non-null    int64
#  4    Occupation       131 non-null    object
#  5    Education Level  131 non-null    object
#  6    Marital Status   131 non-null    object
#  7    Income (USD)     131 non-null    int64
#  8    Favorite Color   131 non-null    object
#  9   Unnamed: 9        0 non-null      float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 10.4+ KB

# %%
df.isnull().any()
# Out:
#  Gender             False
#  Age                False
#  Height (cm)        False
#  Weight (kg)        False
#  Occupation         False
#  Education Level    False
#  Marital Status     False
#  Income (USD)       False
#  Favorite Color     False
# Unnamed: 9           True
# dtype: bool

# %%
df.isnull().sum()
# Out:
#  Gender               0
#  Age                  0
#  Height (cm)          0
#  Weight (kg)          0
#  Occupation           0
#  Education Level      0
#  Marital Status       0
#  Income (USD)         0
#  Favorite Color       0
# Unnamed: 9          131
# dtype: int64

# %%
df.columns
# Out:
# Index([' Gender', ' Age', ' Height (cm)', ' Weight (kg)', ' Occupation',
#        ' Education Level', ' Marital Status', ' Income (USD)',
#        ' Favorite Color', 'Unnamed: 9'],
#       dtype='object')

# %%
df=df.rename(columns={' Gender':'Gender', ' Age':'Age', ' Height (cm)':'Height (cm)', ' Weight (kg)':'Weight (kg)', ' Occupation':'Occupation',
       ' Education Level':'Education Level', ' Marital Status':'Marital Status', ' Income (USD)':'Income (USD)',
       ' Favorite Color':'Favorite Color', 'Unnamed: 9':'Unnamed: 9'})
df
# Out:
#       Gender  Age  Height (cm)  Weight (kg)             Occupation  \
# 0       male   32          175           70      Software Engineer
# 1       male   25          182           85   Sales Representative
# 2     female   41          160           62                 Doctor
# 3       male   38          178           79                 Lawyer
# 4     female   29          165           58       Graphic Designer
# ..       ...  ...          ...          ...                    ...
# 126   female   32          170           64                  Nurse
# 127     male   38          176           79        Project Manager
# 128   female   27          162           55       Graphic Designer
# 129     male   33          175           77   Sales Representative
# 130   female   29          164           57     Software Developer
#
#          Education Level Marital Status  Income (USD) Favorite Color  \
# 0        Master's Degree        Married         75000           Blue
# ...

# %%
df.drop('Unnamed: 9', axis=1, inplace=True)

# %%
df
# Out:
#       Gender  Age  Height (cm)  Weight (kg)             Occupation  \
# 0       male   32          175           70      Software Engineer
# 1       male   25          182           85   Sales Representative
# 2     female   41          160           62                 Doctor
# 3       male   38          178           79                 Lawyer
# 4     female   29          165           58       Graphic Designer
# ..       ...  ...          ...          ...                    ...
# 126   female   32          170           64                  Nurse
# 127     male   38          176           79        Project Manager
# 128   female   27          162           55       Graphic Designer
# 129     male   33          175           77   Sales Representative
# 130   female   29          164           57     Software Developer
#
#          Education Level Marital Status  Income (USD) Favorite Color
# 0        Master's Degree        Married         75000           Blue
# ...

# %%
df.shape
# Out:
# (131, 9)

# %%
df.describe()
# Out:
#               Age  Height (cm)  Weight (kg)   Income (USD)
# count  131.000000   131.000000   131.000000     131.000000
# mean    34.564885   173.198473    71.458015   93206.106870
# std      5.984723     8.045467    12.648052   74045.382919
# min     24.000000   160.000000    50.000000   30000.000000
# 25%     29.000000   166.000000    60.000000   55000.000000
# 50%     34.000000   175.000000    75.000000   75000.000000
# 75%     39.000000   180.500000    83.000000  100000.000000
# max     52.000000   190.000000    94.000000  500000.000000

# %%
df.describe().T
# Out:
#               count          mean           std      min      25%      50%  \
# Age           131.0     34.564885      5.984723     24.0     29.0     34.0
# Height (cm)   131.0    173.198473      8.045467    160.0    166.0    175.0
# Weight (kg)   131.0     71.458015     12.648052     50.0     60.0     75.0
# Income (USD)  131.0  93206.106870  74045.382919  30000.0  55000.0  75000.0
#
#                    75%       max
# Age               39.0      52.0
# Height (cm)      180.5     190.0
# Weight (kg)       83.0      94.0
# Income (USD)  100000.0  500000.0

# %%
df.nunique()
# Out:
# Gender              4
# Age                25
# Height (cm)        27
# Weight (kg)        34
# Occupation         35
# Education Level     8
# Marital Status      7
# Income (USD)       22
# Favorite Color     18
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array([' male', ' female', 'male', 'female'], dtype=object)

# %%
df['Education Level'].unique()
# Out:
# array([" Master's Degree", " Bachelor's Degree", ' Doctorate Degree',
#        " Associate's Degree", "Master's Degree", "Bachelor's Degree",
#        'Doctorate Degree', "Associate's Degree"], dtype=object)

# %%
df['Marital Status'].unique()
# Out:
# array([' Married', ' Single', ' Divorced', ' Widowed', 'Single',
#        'Married', 'Divorced'], dtype=object)

# %%
df['Favorite Color'].unique()
# Out:
# array([' Blue', ' Green', ' Purple', ' Red', ' Yellow', ' Black', ' Pink',
#        ' Orange', ' Grey', 'Blue', 'Green', 'Red', 'Orange', 'Purple',
#        'Yellow', 'Black', 'Grey', 'Pink'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# male       41
# female     39
#  male      27
#  female    24
# Name: Gender, dtype: int64

# %%
df['Education Level'].value_counts()
# Out:
# Bachelor's Degree      49
#  Bachelor's Degree     29
# Associate's Degree     12
#  Master's Degree       10
# Master's Degree        10
# Doctorate Degree        9
#  Doctorate Degree       6
#  Associate's Degree     6
# Name: Education Level, dtype: int64

# %%
df['Marital Status'].value_counts()
# Out:
# Married      41
# Single       38
#  Married     24
#  Single      21
#  Divorced     4
#  Widowed      2
# Divorced      1
# Name: Marital Status, dtype: int64

# %%
px.histogram(df,x ='Marital Status')

# %%
df['Favorite Color'].value_counts()
# Out:
# Blue       13
# Green      13
# Purple     11
# Red        11
# Yellow     10
# Orange      9
#  Green      8
# Black       8
#  Blue       8
#  Pink       6
#  Yellow     6
#  Red        6
#  Purple     6
#  Grey       4
#  Black      4
# Grey        4
#  Orange     3
# Pink        1
# Name: Favorite Color, dtype: int64

# %%
df
# Out:
#       Gender  Age  Height (cm)  Weight (kg)             Occupation  \
# 0       male   32          175           70      Software Engineer
# 1       male   25          182           85   Sales Representative
# 2     female   41          160           62                 Doctor
# 3       male   38          178           79                 Lawyer
# 4     female   29          165           58       Graphic Designer
# ..       ...  ...          ...          ...                    ...
# 126   female   32          170           64                  Nurse
# 127     male   38          176           79        Project Manager
# 128   female   27          162           55       Graphic Designer
# 129     male   33          175           77   Sales Representative
# 130   female   29          164           57     Software Developer
#
#          Education Level Marital Status  Income (USD) Favorite Color
# 0        Master's Degree        Married         75000           Blue
# ...

# %%
df.loc[(df['Marital Status'] == 'Married') , ['Gender', 'Marital Status']]
# Out:
#      Gender Marital Status
# 52   female        Married
# 53     male        Married
# 56   female        Married
# 59     male        Married
# 61     male        Married
# 62   female        Married
# 63     male        Married
# 65     male        Married
# 67     male        Married
# 69     male        Married
# 70   female        Married
# 73     male        Married
# 76   female        Married
# 77     male        Married
# 79     male        Married
# 80     male        Married
# 82     male        Married
# 84     male        Married
# 86     male        Married
# 88     male        Married
# 90     male        Married
# 92     male        Married
# 94     male        Married
# 96     male        Married
# 98     male        Married
# 100    male        Married
# 102    male        Married
# 104    male        Married
# 105    male        Married
# 107    male        Married
# 109    male        Married
# 111    male        Married
# 113    male        Married
# ...

# %%
df.loc[(df["Gender"] == "female") & (df["Marital Status"] == "Married"), ['Gender', 'Marital Status']].reset_index()
# Out:
#    index  Gender Marital Status
# 0     52  female        Married
# 1     56  female        Married
# 2     62  female        Married
# 3     70  female        Married
# 4     76  female        Married

# %%
df.loc[(df['Gender'] == 'female') & (df['Marital Status'] == 'Single'), ['Gender', 'Marital Status']]
# Out:
#      Gender Marital Status
# 54   female         Single
# 58   female         Single
# 60   female         Single
# 64   female         Single
# 66   female         Single
# 68   female         Single
# 72   female         Single
# 74   female         Single
# 78   female         Single
# 81   female         Single
# 83   female         Single
# 85   female         Single
# 87   female         Single
# 89   female         Single
# 91   female         Single
# 93   female         Single
# 95   female         Single
# 97   female         Single
# 99   female         Single
# 101  female         Single
# 103  female         Single
# 106  female         Single
# 108  female         Single
# 110  female         Single
# 112  female         Single
# 114  female         Single
# 116  female         Single
# 118  female         Single
# 120  female         Single
# 122  female         Single
# 124  female         Single
# 126  female         Single
# 128  female         Single
# ...

# %%
df.loc[(df['Marital Status'] == 'Single') &  (df['Age'] >= 20) & (df['Age'] <= 30) , ['Gender', 'Marital Status', 'Age']]
# Out:
#      Gender Marital Status  Age
# 55     male         Single   30
# 58   female         Single   29
# 60   female         Single   26
# 64   female         Single   27
# 66   female         Single   30
# 68   female         Single   29
# 74   female         Single   28
# 78   female         Single   30
# 81   female         Single   27
# 85   female         Single   29
# 89   female         Single   28
# 93   female         Single   30
# 97   female         Single   29
# 103  female         Single   28
# 106  female         Single   27
# 110  female         Single   30
# 112  female         Single   29
# 118  female         Single   28
# 122  female         Single   29
# 128  female         Single   27
# 130  female         Single   29

# %%
df.loc[(df['Gender'] == 'female') & (df['Marital Status'] == 'Single') & (df['Age'] >= 20) & (df['Age'] <= 30), ['Gender', 'Marital Status', 'Age']]
# Out:
#      Gender Marital Status  Age
# 58   female         Single   29
# 60   female         Single   26
# 64   female         Single   27
# 66   female         Single   30
# 68   female         Single   29
# 74   female         Single   28
# 78   female         Single   30
# 81   female         Single   27
# 85   female         Single   29
# 89   female         Single   28
# 93   female         Single   30
# 97   female         Single   29
# 103  female         Single   28
# 106  female         Single   27
# 110  female         Single   30
# 112  female         Single   29
# 118  female         Single   28
# 122  female         Single   29
# 128  female         Single   27
# 130  female         Single   29

# %%
df.loc[(df['Gender'] == 'male') & (df['Education Level'] == "Master's Degree"), ['Gender', 'Education Level']].reset_index()
# Out:
#    index Gender  Education Level
# 0     51   male  Master's Degree
# 1     57   male  Master's Degree
# 2     69   male  Master's Degree
# 3     73   male  Master's Degree
# 4     86   male  Master's Degree
# 5     98   male  Master's Degree
# 6    100   male  Master's Degree
# 7    111   male  Master's Degree
# 8    123   male  Master's Degree
# 9    125   male  Master's Degree

# %%
df.loc[df['Occupation'] == 'Engineer', ['Gender', 'Age']].reset_index()
# Out:
#    index Gender  Age
# 0     51   male   35
# 1     69   male   40
# 2     80   male   37
# 3     98   male   40
# 4    105   male   32
# 5    123   male   40

# %%
df.loc[(df['Occupation'] == 'Doctor') & (df['Gender'] == "female"),['Occupation', 'Gender']].reset_index()
# Out:
#    index Occupation  Gender
# 0     68     Doctor  female
# 1     97     Doctor  female
# 2    122     Doctor  female

# %%
data=df.loc[df['Height (cm)'] > 185, ['Gender', 'Age', 'Height (cm)']].reset_index()
data
# Out:
#    index Gender  Age  Height (cm)
# 0      5   male   45          190
# 1     22   male   40          187
# 2     40   male   45          187
# 3     57   male   44          188
# 4     73   male   45          186

# %%
df.loc[(df['Age'] >= 20) & (df['Age'] <= 30) & (df['Gender'] == 'female'),['Age', 'Gender']]
# Out:
#      Age  Gender
# 52    28  female
# 58    29  female
# 60    26  female
# 64    27  female
# 66    30  female
# 68    29  female
# 74    28  female
# 78    30  female
# 81    27  female
# 85    29  female
# 89    28  female
# 93    30  female
# 97    29  female
# 103   28  female
# 106   27  female
# 110   30  female
# 112   29  female
# 118   28  female
# 122   29  female
# 128   27  female
# 130   29  female

# %%
data=df.loc[(df['Income (USD)'] > 70000) & (df['Gender'] == "female"),['Income (USD)', 'Gender']].reset_index()
data
# Out:
#    index  Income (USD)  Gender
# 0     56         75000  female
# 1     68        120000  female
# 2     95         75000  female
# 3     97        120000  female
# 4    120         75000  female
# 5    122        120000  female

# %%
df.loc[(df['Income (USD)'] > 70000) & (df['Gender'] == "male"),['Income (USD)', 'Gender']]
# Out:
#      Income (USD) Gender
# 51          90000   male
# 53         120000   male
# 55          95000   male
# 57         150000   male
# 59          85000   male
# 61         110000   male
# 63          95000   male
# 65         250000   male
# 67          80000   male
# 69         100000   male
# 71          90000   male
# 73         150000   male
# 77         130000   male
# 79          95000   male
# 80          80000   male
# 82         120000   male
# 84         100000   male
# 86         150000   male
# 88          90000   male
# 90         110000   male
# 92          85000   male
# 94         250000   male
# 98         100000   male
# 100        130000   male
# 102         90000   male
# 104         80000   male
# 105         75000   male
# 107        120000   male
# 109         90000   male
# 111        150000   male
# 113         80000   male
# 115        110000   male
# 117         85000   male
# 119        250000   male
# 123        100000   male
# 125        130000   male
# ...

# %%
df.loc[(df['Age'] >= 20) & (df['Age'] <= 30)  & (df['Income (USD)'] > 70000),['Gender', 'Age', 'Income (USD)']].reset_index()
# Out:
#    index  Gender  Age  Income (USD)
# 0     17    male   28         80000
# 1     55    male   30         95000
# 2     68  female   29        120000
# 3     97  female   29        120000
# 4    122  female   29        120000

# %%
df.loc[(df['Income (USD)'] > 70000) & (df['Occupation'] == "Engineer"),['Gender' ,'Income (USD)',  'Occupation']].reset_index()
# Out:
#    index Gender  Income (USD) Occupation
# 0     51   male         90000   Engineer
# 1     69   male        100000   Engineer
# 2     80   male         80000   Engineer
# 3     98   male        100000   Engineer
# 4    105   male         75000   Engineer
# 5    123   male        100000   Engineer

# %%
dataFrame=df.iloc[:, [df.columns.get_loc('Gender'), df.columns.get_loc('Occupation')]]
dataFrame
# Out:
#       Gender             Occupation
# 0       male      Software Engineer
# 1       male   Sales Representative
# 2     female                 Doctor
# 3       male                 Lawyer
# 4     female       Graphic Designer
# ..       ...                    ...
# 126   female                  Nurse
# 127     male        Project Manager
# 128   female       Graphic Designer
# 129     male   Sales Representative
# 130   female     Software Developer
#
# [131 rows x 2 columns]

# %%
df.iloc[4,2]
# Out:
# 165

# %%
df["Marital Status"].value_counts().values
# Out:
# array([41, 38, 24, 21,  4,  2,  1], dtype=int64)

# %%
df.groupby("Gender")[["Marital Status"]].value_counts().plot.barh()
# Out:
# <AxesSubplot:ylabel='Gender,Marital Status'>

# %%
df.groupby("Gender")[["Marital Status"]].count().reset_index()
# Out:
#     Gender  Marital Status
# 0   female              24
# 1     male              27
# 2   female              39
# 3     male              41

# %%
df.groupby("Occupation")[["Gender"]].count().reset_index()
# Out:
#                Occupation  Gender
# 0              Accountant       3
# 1                 Analyst       3
# 2               Architect       3
# 3        Business Analyst       2
# 4     Business Consultant       1
# 5                     CEO       3
# 6                  Doctor       3
# 7                Engineer       3
# 8        Graphic Designer       3
# 9              IT Manager       3
# 10                 Lawyer       3
# 11   Marketing Specialist       3
# 12                  Nurse       3
# 13        Project Manager       3
# 14   Sales Representative       3
# 15      Software Engineer       1
# 16                Teacher       5
# 17                 Writer       3
# 18             Accountant       3
# 19                Analyst       3
# 20              Architect       4
# 21       Business Analyst       3
# 22                    CEO       3
# 23                 Doctor       6
# 24               Engineer       6
# 25       Graphic Designer       6
# ...

# %%
count = df.groupby("Occupation")[["Gender"]].count().reset_index()
ax = count.plot.bar(x="Occupation", y="Gender")
ax.set_title('Number of Gender in Oppucations')
ax.set_xlabel('Oppucation')
ax.set_ylabel('Gender')
# Out:
# Text(0, 0.5, 'Gender')

# %%
plt.figure(figsize=(5,4))
plt.bar(df["Gender"].value_counts().index,df["Gender"].value_counts().values)
plt.xlabel("Gender")
plt.ylabel("Age")
plt.title("Age distribution by gender")
plt.show()

# %%
data=df.groupby("Occupation")[["Age"]].mean().reset_index()
data
# Out:
#                Occupation        Age
# 0              Accountant  27.333333
# 1                 Analyst  33.333333
# 2               Architect  42.666667
# 3        Business Analyst  40.500000
# 4     Business Consultant  45.000000
# 5                     CEO  48.000000
# 6                  Doctor  39.333333
# 7                Engineer  32.000000
# 8        Graphic Designer  33.333333
# 9              IT Manager  35.666667
# 10                 Lawyer  43.666667
# 11   Marketing Specialist  28.333333
# 12                  Nurse  29.333333
# 13        Project Manager  29.000000
# 14   Sales Representative  27.666667
# 15      Software Engineer  32.000000
# 16                Teacher  32.800000
# 17                 Writer  27.666667
# 18             Accountant  31.000000
# 19                Analyst  36.666667
# 20              Architect  41.750000
# 21       Business Analyst  35.666667
# 22                    CEO  41.000000
# 23                 Doctor  36.166667
# ...

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x="Age", y="Occupation", data=df);

# %%
df.groupby("Gender")[["Income (USD)"]].mean().reset_index()
# Out:
#     Gender   Income (USD)
# 0   female   63125.000000
# 1     male  135925.925926
# 2   female   62820.512821
# 3     male  111585.365854

# %%
sns.boxplot(x="Gender",y="Income (USD)",data=df);

# %%
sns.barplot(x="Income (USD)",y="Education Level",data=df)
# Out:
# <AxesSubplot:xlabel='Income (USD)', ylabel='Education Level'>

# %%
df.groupby("Gender")[["Age"]].mean().reset_index().sort_values(by="Age" , ascending=True)
# Out:
#     Gender        Age
# 2   female  30.333333
# 0   female  30.833333
# 1     male  37.555556
# 3     male  38.804878

# %%
df.groupby("Gender")[["Height (cm)"]].mean().reset_index().sort_values(by="Height (cm)" , ascending=True)
# Out:
#     Gender  Height (cm)
# 0   female   165.458333
# 2   female   165.846154
# 1     male   180.000000
# 3     male   180.243902

# %%
kb = df[df["Gender"] == "female"]["Height (cm)"]
eb = df[df["Gender"] == "male"]["Height (cm)"]
kadin_ortalama = kb.mean()
erkek_ortalama = eb.mean()
plt.hist(kb, label="Female")
plt.hist(eb, label="Male")
plt.title("Height Distribution of Persons by Gender")
plt.xlabel("Size")
plt.ylabel("Number")
plt.axvline(x=kadin_ortalama, color="blue", linestyle="--", label="Average of Female")
plt.axvline(x=erkek_ortalama, color="red", linestyle="--", label="Average of Male")
plt.legend()

# %%
df.groupby("Gender")[["Weight (kg)"]].mean().reset_index().sort_values(by="Weight (kg)" , ascending=True)
# Out:
#     Gender  Weight (kg)
# 2   female    59.179487
# 0   female    59.416667
# 1     male    82.407407
# 3     male    82.975610

# %%
df[df['Education Level']=="Doctorate Degree"].reset_index()
# Out:
#    index  Gender  Age  Height (cm)  Weight (kg) Occupation   Education Level  \
# 0     53    male   42          185           90     Doctor  Doctorate Degree
# 1     65    male   41          180           86        CEO  Doctorate Degree
# 2     68  female   29          164           56     Doctor  Doctorate Degree
# 3     82    male   44          182           88     Doctor  Doctorate Degree
# 4     94    male   42          184           90        CEO  Doctorate Degree
# 5     97  female   29          166           58     Doctor  Doctorate Degree
# 6    107    male   44          182           88     Doctor  Doctorate Degree
# 7    119    male   40          183           86        CEO  Doctorate Degree
# 8    122  female   29          165           57     Doctor  Doctorate Degree
#
#   Marital Status  Income (USD) Favorite Color
# 0        Married        120000            Red
# 1        Married        250000         Orange
# 2         Single        120000            Red
# ...

# %%
sns.scatterplot(x="Weight (kg)",y="Height (cm)",data=df);

# %%
plt.figure(figsize=(12,7))
px.bar(df, x="Age", y="Income (USD)")

# %%
ort = df.groupby(['Occupation'])['Income (USD)'].mean()
ort.plot(kind='bar')
plt.title('Average Income of Occupations')
plt.xlabel('Occupation')
plt.ylabel('Income (USD)')
# Out:
# Text(0, 0.5, 'Income (USD)')

# %%
count = df.groupby(['Marital Status', 'Gender'])['Gender'].count().unstack()
married_count = count.loc['Married'].sum()
single_count = count.loc['Single'].sum()
plt.figure(figsize=(4, 4))
plt.bar(['Married', 'Single'], [married_count, single_count], width=0.3)
plt.title('Number of Married-Single')
plt.xlabel('Marital status')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
age_marital_status = df.groupby("Marital Status")["Age"].mean().reset_index()

sns.barplot(x="Marital Status", y="Age", data = age_marital_status)
# Out:
# <AxesSubplot:xlabel='Marital Status', ylabel='Age'>

# %%
sns.pairplot(df)

# %%
gender_counts = df["Occupation"].value_counts(normalize=True)

counts = {}
for col in df.columns:
    counts[col] = df[col].value_counts(normalize=True)

# %%
plt.figure(figsize=(10,10))
plt.pie(counts["Occupation"], labels=counts["Occupation"].index)
plt.title("Occupation Distribution")
# Out:
# Text(0.5, 1.0, 'Occupation Distribution')
